# %% [markdown]
# # Test joblib model

# %%
import joblib

model = joblib.load('../model_development/artifact.joblib')
model
# Out:
# {'model': LinearRegression(),
#  'scaler': MinMaxScaler(),
#  'features':      Trip_Distance_km  Trip_Duration_Minutes  Passenger_Count  \
#  0               19.35                  53.82              3.0
#  1               36.87                  37.27              1.0
#  2               25.87                  22.64              3.0
#  3                8.64                  89.33              2.0
#  4               43.44                  61.57              3.0
#  ..                ...                    ...              ...
#  711             25.87                  25.61              3.0
#  712             18.69                  79.41              3.0
#  713              7.70                  54.18              3.0
#  714             47.56                 114.94              1.0
#  715             22.85                  29.69              3.0
#
#       Time_of_Day_Evening  Time_of_Day_Morning  Time_of_Day_Night
#  0                  False                 True              False
# ...
